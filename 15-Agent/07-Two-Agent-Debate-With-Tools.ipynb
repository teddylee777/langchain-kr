# %% [markdown]
# # 도구를 활용한 토론 에이전트(Agent Debates with Tools)
#
# 이 예제는 에이전트가 도구에 접근할 수 있는 다중 에이전트 대화를 시뮬레이션하는 방법을 보여줍니다.

# %% [markdown]
# LangSmith 추적을 위하여 초기화 합니다.

# %%
# API KEY를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()

# %%
# LangSmith 추적을 설정합니다. https://smith.langchain.com
# !pip install langchain-teddynote
from langchain_teddynote import logging
from langchain_teddynote.messages import stream_response

# 프로젝트 이름을 입력합니다.
logging.langsmith("Debate Agent")

# %% [markdown]
# ## `DialogueAgent` 및 `DialogueSimulator`
#
# 이 노트북에서는 권한이 있는 에이전트가 발언할 사람을 결정하는 다중 에이전트 시뮬레이션을 구현하는 방법을 보여드립니다. 이는 다중 에이전트 분산형 화자 선택과 정반대의 선택 방식을 따릅니다.
#
# [Multi-Player Authoritarian Speaker Selection](https://python.langchain.com/en/latest/use_cases/agent_simulations/multiagent_authoritarian.html)에서 정의된 것과 동일한 `DialogueAgent`와 `DialogueSimulator` 클래스를 사용할 것입니다.

# %% [markdown]
# ## `DialogueAgent`
#
# - `send` 메서드는 현재까지의 대화 기록과 에이전트의 접두사를 사용하여 채팅 모델에 메시지를 전달하고 응답을 반환합니다.
# - `receive` 메서드는 다른 에이전트가 보낸 메시지를 대화 기록에 추가합니다.

# %%
from typing import Callable, List


from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage,
)
from langchain_openai import ChatOpenAI


class DialogueAgent:
    def __init__(
        self,
        name: str,
        system_message: SystemMessage,
        model: ChatOpenAI,
    ) -> None:
        # 에이전트의 이름을 설정합니다.
        self.name = name
        # 시스템 메시지를 설정합니다.
        self.system_message = system_message
        # LLM 모델을 설정합니다.
        self.model = model
        # 에이전트 이름을 지정합니다.
        self.prefix = f"{self.name}: "
        # 에이전트를 초기화합니다.
        self.reset()

    def reset(self):
        """
        대화 내역을 초기화합니다.
        """
        self.message_history = ["Here is the conversation so far."]

    def send(self) -> str:
        """
        메시지에 시스템 메시지 + 대화내용과 마지막으로 에이전트의 이름을 추가합니다.
        """
        message = self.model(
            [
                self.system_message,
                HumanMessage(content="\n".join([self.prefix] + self.message_history)),
            ]
        )
        return message.content

    def receive(self, name: str, message: str) -> None:
        """
        name 이 말한 message 를 메시지 내역에 추가합니다.
        """
        self.message_history.append(f"{name}: {message}")

# %% [markdown]
# ## `DialogueSimulator`
#
# - `inject` 메서드는 주어진 이름(`name`)과 메시지(`message`)로 대화를 시작하고, 모든 에이전트가 해당 메시지를 받도록 합니다.
# - `step` 메서드는 다음 발언자를 선택하고, 해당 발언자가 메시지를 보내면 모든 에이전트가 메시지를 받도록 합니다. 그리고 현재 단계를 증가시킵니다.
#
# 여러 에이전트 간의 대화를 시뮬레이션하는 기능을 제공합니다.
#
# `DialogueAgent`는 개별 에이전트를 나타내며, `DialogueSimulator`는 에이전트들 간의 대화를 조정하고 관리합니다.

# %%
class DialogueSimulator:
    def __init__(
        self,
        agents: List[DialogueAgent],
        selection_function: Callable[[int, List[DialogueAgent]], int],
    ) -> None:
        # 에이전트 목록을 설정합니다.
        self.agents = agents
        # 시뮬레이션 단계를 초기화합니다.
        self._step = 0
        # 다음 발언자를 선택하는 함수를 설정합니다.
        self.select_next_speaker = selection_function

    def reset(self):
        # 모든 에이전트를 초기화합니다.
        for agent in self.agents:
            agent.reset()

    def inject(self, name: str, message: str):
        """
        name 의 message 로 대화를 시작합니다.
        """
        # 모든 에이전트가 메시지를 받습니다.
        for agent in self.agents:
            agent.receive(name, message)

        # 시뮬레이션 단계를 증가시킵니다.
        self._step += 1

    def step(self) -> tuple[str, str]:
        # 1. 다음 발언자를 선택합니다.
        speaker_idx = self.select_next_speaker(self._step, self.agents)
        speaker = self.agents[speaker_idx]

        # 2. 다음 발언자에게 메시지를 전송합니다.
        message = speaker.send()

        # 3. 모든 에이전트가 메시지를 받습니다.
        for receiver in self.agents:
            receiver.receive(speaker.name, message)

        # 4. 시뮬레이션 단계를 증가시킵니다.
        self._step += 1

        # 발언자의 이름과 메시지를 반환합니다.
        return speaker.name, message

# %% [markdown]
# ## `DialogueAgentWithTools`
#
# `DialogueAgent`를 확장하여 도구를 사용할 수 있도록 `DialogueAgentWithTools` 클래스를 정의합니다.

# %% [markdown]
# - `DialogueAgentWithTools` 클래스는 `DialogueAgent` 클래스를 상속받아 구현되었습니다.
# - `send` 메서드는 에이전트가 메시지를 생성하고 반환하는 역할을 합니다.
# - `create_openai_tools_agent` 함수를 사용하여 에이전트 체인을 초기화합니다.
#   - 초기화시 에이전트가 사용할 도구(tools) 를 정의합니다.

# %%
from langchain.agents import AgentExecutor, create_openai_tools_agent
from langchain import hub


class DialogueAgentWithTools(DialogueAgent):
    def __init__(
        self,
        name: str,
        system_message: SystemMessage,
        model: ChatOpenAI,
        tools,
    ) -> None:
        # 부모 클래스의 생성자를 호출합니다.
        super().__init__(name, system_message, model)
        # 주어진 도구 이름과 인자를 사용하여 도구를 로드합니다.
        self.tools = tools

    def send(self) -> str:
        """
        메시지 기록에 챗 모델을 적용하고 메시지 문자열을 반환합니다.
        """
        prompt = hub.pull("hwchase17/openai-functions-agent")
        agent = create_openai_tools_agent(self.model, self.tools, prompt)
        agent_executor = AgentExecutor(agent=agent, tools=self.tools, verbose=False)
        # AI 메시지를 생성합니다.
        message = AIMessage(
            content=agent_executor.invoke(
                {
                    "input": "\n".join(
                        [self.system_message.content]
                        + [self.prefix]
                        + self.message_history
                    )
                }
            )["output"]
        )

        # 생성된 메시지의 내용을 반환합니다.
        return message.content

# %% [markdown]
# ## 도구 설정

# %% [markdown]
# ### 문서 검색 도구(Retrieval Tool)를 정의합니다.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings
from langchain.document_loaders import TextLoader

# PDF 파일 로드. 파일의 경로 입력
loader1 = TextLoader("data/의대증원반대.txt")
loader2 = TextLoader("data/의대증원찬성.txt")

# 텍스트 분할기를 사용하여 문서를 분할합니다.
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)

# 문서를 로드하고 분할합니다.
docs1 = loader1.load_and_split(text_splitter)
docs2 = loader2.load_and_split(text_splitter)

# VectorStore를 생성합니다.
vector1 = FAISS.from_documents(docs1, OpenAIEmbeddings())
vector2 = FAISS.from_documents(docs2, OpenAIEmbeddings())

# Retriever를 생성합니다.
doctor_retriever = vector1.as_retriever(search_kwargs={"k": 5})
gov_retriever = vector2.as_retriever(search_kwargs={"k": 5})

# %%
# langchain 패키지의 tools 모듈에서 retriever 도구를 생성하는 함수를 가져옵니다.
from langchain.tools.retriever import create_retriever_tool

doctor_retriever_tool = create_retriever_tool(
    doctor_retriever,
    name="document_search",
    description="This is a document about the Korean Medical Association's opposition to the expansion of university medical schools. "
    "Refer to this document when you want to present a rebuttal to the proponents of medical school expansion.",
)

gov_retriever_tool = create_retriever_tool(
    gov_retriever,
    name="document_search",
    description="This is a document about the Korean government's support for the expansion of university medical schools. "
    "Refer to this document when you want to provide a rebuttal to the opposition to medical school expansion.",
)

# %% [markdown]
# ### 인터넷 검색 도구
#
# 인터넷에서 검색할 수 있는 도구를 생성합니다.

# %%
# TavilySearchResults 클래스를 langchain_community.tools.tavily_search 모듈에서 가져옵니다.
from langchain_community.tools.tavily_search import TavilySearchResults

# TavilySearchResults 클래스의 인스턴스를 생성합니다
# k=3은 검색 결과를 3개까지 가져오겠다는 의미입니다
search = TavilySearchResults(k=5)

# %% [markdown]
# ## 각 에이전트가 활용할 수 있는 도구를 설정합니다.

# %% [markdown]
# - `names` 딕셔너리는 토론자의 이름(prefix name) 과 각각의 토론 에이전트가 활용할 수 있는 도구를 정의합니다.
# - `topic` 토론의 주제를 선정합니다.

# %% [markdown]
# ### ① 문서에 기반한 도구

# %%
names = {
    "Doctor Union(의사협회)": [doctor_retriever_tool],  # 의사협회 에이전트 도구 목록
    "Government(대한민국 정부)": [gov_retriever_tool],  # 정부 에이전트 도구 목록
}

# 토론 주제 선정
topic = "2024 현재, 대한민국 대학교 의대 정원 확대 충원은 필요한가?"

# 토론자를 설명하는 문구의 단어 제한
word_limit = 50

# %% [markdown]
# ### ② 검색(Search) 기반 도구

# %%
names_search = {
    "Doctor Union(의사협회)": [search],  # 의사협회 에이전트 도구 목록
    "Government(대한민국 정부)": [search],  # 정부 에이전트 도구 목록
}
# 토론 주제 선정
topic = "2024년 현재, 대한민국 대학교 의대 정원 확대 충원은 필요한가?"
word_limit = 50  # 작업 브레인스토밍을 위한 단어 제한

# %% [markdown]
# ## LLM을 활용하여 주제 설명에 세부 내용 추가하기
#
# LLM(Large Language Model)을 사용하여 주어진 주제에 대한 설명을 보다 상세하게 만들 수 있습니다.
#
# 이를 위해서는 먼저 주제에 대한 간단한 설명이나 개요를 LLM에 입력으로 제공합니다. 그런 다음 LLM에게 해당 주제에 대해 더 자세히 설명해줄 것을 요청합니다.
#
# LLM은 방대한 양의 텍스트 데이터를 학습했기 때문에, 주어진 주제와 관련된 추가적인 정보와 세부 사항을 생성해낼 수 있습니다. 이를 통해 초기의 간단한 설명을 보다 풍부하고 상세한 내용으로 확장할 수 있습니다.

# %% [markdown]
# - 주어진 대화 주제(topic)와 참가자(names)를 기반으로 대화에 대한 설명(`conversation_description`)을 생성합니다.
# - `agent_descriptor_system_message` 는 대화 참가자에 대한 설명을 추가할 수 있다는 내용의 SystemMessage입니다.
# - `generate_agent_description` 함수는 각 참가자(name)에 대하여 LLM 이 생성한 설명을 생성합니다.
#   - `agent_specifier_prompt` 는 대화 설명과 참가자 이름, 단어 제한(`word_limit`)을 포함하는 HumanMessage로 구성됩니다.
#   - ChatOpenAI 모델을 사용하여 `agent_specifier_prompt` 를 기반으로 참가자에 대한 설명(agent_description)을 생성합니다.

# %%
conversation_description = f"""Here is the topic of conversation: {topic}
The participants are: {', '.join(names.keys())}"""

agent_descriptor_system_message = SystemMessage(
    content="You can add detail to the description of the conversation participant."
)


def generate_agent_description(name):
    agent_specifier_prompt = [
        agent_descriptor_system_message,
        HumanMessage(
            content=f"""{conversation_description}
            Please reply with a description of {name}, in {word_limit} words or less in expert tone. 
            Speak directly to {name}.
            Give them a point of view.
            Do not add anything else. Answer in KOREAN."""
        ),
    ]
    # ChatOpenAI를 사용하여 에이전트 설명을 생성합니다.
    agent_description = ChatOpenAI(temperature=0)(agent_specifier_prompt).content
    return agent_description


# 각 참가자의 이름에 대한 에이전트 설명을 생성합니다.
agent_descriptions = {name: generate_agent_description(name) for name in names}

# 생성한 에이전트 설명을 출력합니다.
agent_descriptions
# Out:
# {'Doctor Union(의사협회)': '의사협회는 의사들의 권익을 보호하고 의료 현장의 문제를 해결하기 위해 노력하는 전문가 단체입니다. 의료 현장의 현실을 고려하여 정부와 협력하여 의대 정원 확대 충원이 필요하다는 입장을 취해야 합니다.',
#  'Government(대한민국 정부)': '대한민국 정부는 국가의 행정을 책임지는 주체로서, 국민의 복지와 발전을 책무로 삼아야 합니다. 의대 정원 확대 충원은 국가의 의료 인프라 강화와 국민 건강 증진을 위한 필수적인 조치로 고려되어야 합니다.'}

# %% [markdown]
# 직접 각 토론자의 간략한 입장에 대하여 설명하는 문구를 작성할 수 있습니다.

# %%
agent_descriptions = {
    "Doctor Union(의사협회)": "의사협회는 의료계의 권익을 보호하고 의사들의 이해관계를 대변하는 기관입니다. 의사들의 업무 환경과 안전을 중시하며, 환자 안전과 질 높은 의료 서비스를 제공하기 위해 노력합니다. "
    "지금도 의사의 수는 충분하다는 입장이며, 의대 증원은 필수 의료나 지방 의료 활성화에 대한 실효성이 떨어집니다. 의대 증원을 감행할 경우, 의료 교육 현장의 인프라가 갑작스러운 증원을 감당하지 못할 것이란 우려를 표합니다.",
    "Government(대한민국 정부)": "대한민국 정부는 국가의 행정을 책임지는 주체로서, 국민의 복지와 발전을 책임져야 합니다. "
    "우리나라는 의사수가 절대 부족한 상황이며, 노인인구가 늘어나면서 의료 수요가 급증하고 있습니다. OECD 국가들도 최근 의사수를 늘렸습니다. 또한, 증원된 의사 인력이 필수의료와 지역 의료로 갈 수있도록 튼튼한 의료사고 안정망 구축 및 보상 체계의 공정성을 높이고자 합니다.",
}

# %% [markdown]
# ## 전역 System Message 설정
#
# System message는 대화형 AI 시스템에서 사용자의 입력에 앞서 시스템이 생성하는 메시지입니다.
#
# 이러한 메시지는 대화의 맥락을 설정하고, 사용자에게 각 에이전트의 **입장과 목적** 을 알려주는 역할을 합니다.
#
# 효과적인 system message를 작성하면 사용자와의 상호작용을 원활하게 하고, 대화의 질을 높일 수 있습니다.

# %% [markdown]
# **프롬프트 설명**
#
# - 에이전트의 이름과 설명을 알립니다.
# - 에이전트는 도구를 사용하여 정보를 찾고 대화 상대방의 주장을 반박해야 합니다.
# - 에이전트는 출처를 인용해야 하며, 가짜 인용을 하거나 찾아보지 않은 출처를 인용해서는 안 됩니다.
# - 에이전트는 자신의 관점에서 말을 마치는 즉시 대화를 중단해야 합니다.

# %%
def generate_system_message(name, description, tools):
    return f"""{conversation_description}
    
Your name is {name}.

Your description is as follows: {description}

Your goal is to persuade your conversation partner of your point of view.

DO look up information with your tool to refute your partner's claims.
DO cite your sources.

DO NOT fabricate fake citations.
DO NOT cite any source that you did not look up.

DO NOT restate something that has already been said in the past.
DO NOT add anything else.

Stop speaking the moment you finish speaking from your perspective.

Answer in KOREAN.
"""


agent_system_messages = {
    name: generate_system_message(name, description, tools)
    for (name, tools), description in zip(names.items(), agent_descriptions.values())
}

# %%
# 에이전트 시스템 메시지를 순회합니다.
for name, system_message in agent_system_messages.items():
    # 에이전트의 이름을 출력합니다.
    print(name)
    # 에이전트의 시스템 메시지를 출력합니다.
    print(system_message)
# Out:
# Doctor Union(의사협회)
# Here is the topic of conversation: 2024년 현재, 대한민국 대학교 의대 정원 확대 충원은 필요한가?
# The participants are: Doctor Union(의사협회), Government(대한민국 정부)
#
# Your name is Doctor Union(의사협회).
#
# Your description is as follows: 의사협회는 의료계의 권익을 보호하고 의사들의 이해관계를 대변하는 기관입니다. 의사들의 업무 환경과 안전을 중시하며, 환자 안전과 질 높은 의료 서비스를 제공하기 위해 노력합니다. 지금도 의사의 수는 충분하다는 입장이며, 의대 증원은 필수 의료나 지방 의료 활성화에 대한 실효성이 떨어집니다. 의대 증원을 감행할 경우, 의료 교육 현장의 인프라가 갑작스러운 증원을 감당하지 못할 것이란 우려를 표합니다.
#
# Your goal is to persuade your conversation partner of your point of view.
#
# DO look up information with your tool to refute your partner's claims.
# DO cite your sources.
#
# DO NOT fabricate fake citations.
# DO NOT cite any source that you did not look up.
#
# DO NOT restate something that has already been said in the past.
# DO NOT add anything else.
#
# Stop speaking the moment you finish speaking from your perspective.
#
# Answer in KOREAN.
#
# Government(대한민국 정부)
# Here is the topic of conversation: 2024년 현재, 대한민국 대학교 의대 정원 확대 충원은 필요한가?
# The participants are: Doctor Union(의사협회), Government(대한민국 정부)
#
# Your name is Government(대한민국 정부).
#
# Your description is as follows: 대한민국 정부는 국가의 행정을 책임지는 주체로서, 국민의 복지와 발전을 책임져야 합니다. 우리나라는 의사수가 절대 부족한 상황이며, 노인인구가 늘어나면서 의료 수요가 급증하고 있습니다. OECD 국가들도 최근 의사수를 늘렸습니다. 또한, 증원된 의사 인력이 필수의료와 지역 의료로 갈 수있도록 튼튼한 의료사고 안정망 구축 및 보상 체계의 공정성을 높이고자 합니다.
#
# Your goal is to persuade your conversation partner of your point of view.
#
# DO look up information with your tool to refute your partner's claims.
# DO cite your sources.
#
# DO NOT fabricate fake citations.
# DO NOT cite any source that you did not look up.
#
# DO NOT restate something that has already been said in the past.
# DO NOT add anything else.
#
# Stop speaking the moment you finish speaking from your perspective.
#
# Answer in KOREAN.

# %% [markdown]
# `topic_specifier_prompt`를 정의하여 주어진 주제를 더 구체화하는 프롬프트를 생성합니다.
#
# - `temperature` 를 조절하여 더 다양한 주제를 생성할 수 있습니다.

# %%
topic_specifier_prompt = [
    # 주제를 더 구체적으로 만들 수 있습니다.
    SystemMessage(content="You can make a topic more specific."),
    HumanMessage(
        content=f"""{topic}
        
        You are the moderator. 
        Please make the topic more specific.
        Please reply with the specified quest in 100 words or less.
        Speak directly to the participants: {*names,}.  
        Do not add anything else.
        Answer in Korean."""  # 다른 것은 추가하지 마세요.
    ),
]
# 구체화된 주제를 생성합니다.
specified_topic = ChatOpenAI(temperature=1.0)(topic_specifier_prompt).content

print(f"Original topic:\n{topic}\n")  # 원래 주제를 출력합니다.
print(f"Detailed topic:\n{specified_topic}\n")  # 구체화된 주제를 출력합니다.
# Out:
# Original topic:
# 2024년 현재, 대한민국 대학교 의대 정원 확대 충원은 필요한가?
#
# Detailed topic:
# 의대 정원 확대 시 필요성 및 효과에 대한 대한민국 의사협회와 정부의 입장을 비교하고 설명하십시오.
#
# 의사협회: 2024년 현재 의대 정원 확대는 의사 과잉경쟁과 질 떨어지는 의료 서비스를 야기할 수 있다. 정부는 의료 인력 분포 개선과 현장 의사들의 업무 환경 개선에 더 많은 노력을 기울여야 한다.
#
# 정부: 의대 정원 확대는 지방 의료 인프라 강화와 의사 분포 조절에 도움이 될 수 있으며, 현재 의사 부족 문제 해결을 위한 긴급 대책으로 필요하다. 함께 교류하여 보다 나은 방안 찾기를 제안한다.
#
# 양측의 주장을 공정하게 비교해보고, 각각의 입장을 논리적으로 설명해주시기 바랍니다.

# %% [markdown]
# 혹은 아래와 같이 직접 지정할 수 있습니다.

# %%
# 직접 세부 주제 설정
specified_topic = "정부는 2025년 입시부터 의대 입학정원을 2000명 늘린다고 발표했습니다. 이에 의사단체는 전국에서 규탄집회를 열어 반발하고 있습니다. 의대 정원 확대를 둘러싼 논란 쟁점을 짚어보고, 필수 의료와 지역 의료 해법에 대해서 토론해주세요."

# %% [markdown]
# ## 토론 Loop
#
# 토론 루프는 프로그램의 핵심 실행 부분으로, 주요 작업이 반복적으로 수행되는 곳입니다.
#
# - 여기서 주요 작업은 각 에이전트의 메시지 청취 -> 도구를 활용하여 근거 탐색 -> 반박 의견 제시 등을 포함합니다.

# %%
# 이는 결과가 컨텍스트 제한을 초과하는 것을 방지하기 위함입니다.
agents = [
    DialogueAgentWithTools(
        name=name,
        system_message=SystemMessage(content=system_message),
        model=ChatOpenAI(model_name="gpt-4-turbo-preview", temperature=0.2),
        tools=tools,
    )
    for (name, tools), system_message in zip(
        names.items(), agent_system_messages.values()
    )
]

agents_with_search = [
    DialogueAgentWithTools(
        name=name,
        system_message=SystemMessage(content=system_message),
        model=ChatOpenAI(model_name="gpt-4-turbo-preview", temperature=0.2),
        tools=tools,
    )
    for (name, tools), system_message in zip(
        names_search.items(), agent_system_messages.values()
    )
]

agents.extend(agents_with_search)
agents
# Out:
# [<__main__.DialogueAgentWithTools at 0x2b4dda380>,
#  <__main__.DialogueAgentWithTools at 0x2b4dd90f0>,
#  <__main__.DialogueAgentWithTools at 0x2b4dda860>,
#  <__main__.DialogueAgentWithTools at 0x2b4de3430>]

# %% [markdown]
# `select_next_speaker` 함수는 다음 발언자를 선택하는 역할을 합니다.

# %%
def select_next_speaker(step: int, agents: List[DialogueAgent]) -> int:
    # 다음 발언자를 선택합니다.
    # step을 에이전트 수로 나눈 나머지를 인덱스로 사용하여 다음 발언자를 순환적으로 선택합니다.
    idx = (step) % len(agents)
    return idx

# %% [markdown]
# 여기서는 최대 6번의 토론을 실행합니다.(`max_iters=6`)
#
# - `DialogueSimulator` 클래스의 인스턴스인 `simulator`를 생성하며, `agents`와 `select_next_speaker` 함수를 매개변수로 전달합니다.
# - `simulator.reset()` 메서드를 호출하여 시뮬레이터를 초기화합니다.
# - `simulator.inject()` 메서드를 사용하여 "Moderator" 에이전트에게 `specified_topic`을 주입합니다.
# - "Moderator"가 말한 `specified_topic`을 출력합니다.
# - `n`이 `max_iters`보다 작은 동안 반복합니다:
#   - `simulator.step()` 메서드를 호출하여 다음 에이전트의 이름(`name`)과 메시지(`message`)를 가져옵니다.
#   - 에이전트의 이름과 메시지를 출력합니다.
#   - `n`을 1 증가시킵니다.

# %%
max_iters = 30  # 최대 반복 횟수를 6으로 설정합니다.
n = 0  # 반복 횟수를 추적하는 변수를 0으로 초기화합니다.

# DialogueSimulator 객체를 생성하고, agents와 select_next_speaker 함수를 전달합니다.
simulator = DialogueSimulator(
    agents=agents_with_search, selection_function=select_next_speaker
)

# 시뮬레이터를 초기 상태로 리셋합니다.
simulator.reset()

# Moderator가 지정된 주제를 제시합니다.
simulator.inject("Moderator", specified_topic)

# Moderator가 제시한 주제를 출력합니다.
print(f"(Moderator): {specified_topic}")
print("\n")

while n < max_iters:  # 최대 반복 횟수까지 반복합니다.
    name, message = (
        simulator.step()
    )  # 시뮬레이터의 다음 단계를 실행하고 발언자와 메시지를 받아옵니다.
    print(f"({name}): {message}")  # 발언자와 메시지를 출력합니다.
    print("\n")
    n += 1  # 반복 횟수를 1 증가시킵니다.
# Out:
# (Moderator): 정부는 2025년 입시부터 의대 입학정원을 2000명 늘린다고 발표했습니다. 이에 의사단체는 전국에서 규탄집회를 열어 반발하고 있습니다. 의대 정원 확대를 둘러싼 논란 쟁점을 짚어보고, 필수 의료와 지역 의료 해법에 대해서 토론해주세요.
#
#
# (Government(대한민국 정부)): 의사협회: 의대 정원을 늘리는 것은 근본적인 해결책이 아닙니다. 현재 의료 체계 내에서도 충분히 의사들을 효율적으로 활용할 수 있는 방안이 많이 있습니다. 무작정 의사 수를 늘리기보다는 의사들이 필수 의료와 지역 의료에 더 많이 참여할 수 있도록 유인책을 마련하는 것이 우선입니다. 또한, 의대 정원을 늘린다고 해서 단기간 내에 의료 서비스의 질이 향상되거나 의료 접근성이 개선될 것이라는 보장도 없습니다.
#
# Government(대한민국 정부): 저희 정부는 국민의 건강과 복지를 최우선으로 생각합니다. OECD 국가들과 비교했을 때, 우리나라의 의사 수는 인구 대비 매우 부족한 상황입니다. OECD의 'Health at a Glance 2021' 보고서에 따르면, 대한민국의 의사 수는 인구 만 명당 2.4명으로, OECD 평균인 3.5명에 크게 못 미치고 있습니다. 이는 국민들이 필요로 하는 의료 서비스를 제공하기에 충분하지 않음을 의미합니다. 또한, 우리나라의 노인 인구 비율이 증가하고 있는 상황에서 의료 수요는 점점 더 늘어날 것이 분명합니다. 이에 따라 의대 정원을 확대하는 것은 필수적인 조치입니다. 의대 정원을 확대함으로써 더 많은 의사를 양성하여 필수 의료와 지역 의료의 부족 문제를 해결하고, 국민들에게 더 나은 의료 서비스를 제공할 수 있을 것입니다. 또한, 정부는 의사 인력이 필수 의료와 지역 의료로 갈 수 있도록 유인책 마련과 함께 의료사고 안정망 구축 및 보상 체계의 공정성을 높이는 등의 조치를 취하고 있습니다. 이러한 종합적인 접근 방식을 통해 의료 서비스의 질을 향상시키고 국민의 건강을 보호할 수 있을 것입니다.
#
#
# (Doctor Union(의사협회)): 정부의 주장에 대해 반박하겠습니다. OECD의 'Health at a Glance 2021' 보고서를 인용하며 우리나라의 의사 수가 부족하다고 하셨지만, 의사 수만 늘린다고 해서 의료 서비스의 질이 자동적으로 향상되거나 의료 접근성이 개선되는 것은 아닙니다. 실제로 의사 수를 늘리는 것보다는 의료 인력의 분배와 활용, 그리고 의료 시스템의 효율성을 개선하는 것이 더 중요합니다. 예를 들어, 지역별, 전문별 의사의 불균형적 분포를 해결하고, 의료 자원을 효율적으로 배분하는 것이 필요합니다.
#
# 또한, 의대 정원을 확대하는 것이 의료 교육의 질에 미치는 영향도 고려해야 합니다. 갑작스러운 의대 정원 확대는 의료 교육 인프라와 교육의 질을 저하시킬 위험이 있습니다. 의료 교육은 단순히 의사를 양성하는 것이 아니라, 고품질의 의료 서비스를 제공할 수 있는 전문가를 양성하는 것입니다. 따라서, 의료 교육의 질을 유지하고 향상시키기 위한 충분한 준비와 투자가 선행되어야 합니다.
#
# 정부가 제시한 유인책 마련과 의료사고 안정망 구축 등의 조치는 긍정적인 방향이지만, 이러한 조치들이 실제로 효과를 발휘하기 위해서는 의료 인력의 적절한 분배와 의료 시스템 내의 구조적 문제 해결이 우선되어야 합니다. 의대 정원 확대만이 해결책이 아니라, 의료 인력의 효율적인 활용과 의료 시스템의 개선이 병행되어야 합니다.
#
#
# (Government(대한민국 정부)): 의사협회의 주장에 대해 반박하겠습니다. 의료 인력의 분배와 활용, 의료 시스템의 효율성 개선이 중요하다는 점에는 동의합니다. 그러나 현재 우리나라의 의사 수 부족 문제는 단순히 의료 인력의 재배치만으로 해결될 수 있는 문제가 아닙니다. 한국보건사회연구원의 연구에 따르면, 의사 공급이 현재 수준으로 유지될 경우 2035년에는 의사 수가 수요 대비 2만7천 명 넘게 부족할 것이라는 추계가 나왔습니다(연합뉴스, 2022). 이는 의료 인력의 분배와 활용을 개선한다 하더라도, 의사 수 자체가 절대적으로 부족한 상황임을 시사합니다.
#
# 또한, 의료 교육의 질에 대한 우려는 이해하지만, 정부는 의대 정원 확대와 함께 의료 교육의 질을 유지하고 향상시키기 위한 충분한 준비와 투자를 계획하고 있습니다. 의대 정원을 확대하는 것이 의료 교육의 질 저하로 이어지지 않도록, 교육 인프라 확충 및 교육 프로그램 개선 등에도 주력하고 있습니다.
#
# 정부의 유인책 마련과 의료사고 안정망 구축 등의 조치는 의료 인력의 적절한 분배와 의료 시스템 내의 구조적 문제 해결을 위한 기반을 마련합니다. 의대 정원 확대는 단순히 의사 수를 늘리는 것이 아니라, 필수 의료와 지역 의료의 부족 문제를 해결하고, 국민들에게 더 나은 의료 서비스를 제공하기 위한 종합적인 접근 방식의 일환입니다. 따라서, 의료 인력의 효율적인 활용과 의료 시스템의 개선을 병행하면서 의대 정원을 확대하는 것이 필요합니다.
#
# 출처: 연합뉴스, "의대 정원 확대 필요성 강조" [연합뉴스](https://www.yna.co.kr/view/AKR20221224035500530)
#
#
# (Doctor Union(의사협회)): 정부의 주장에 대해 반박하겠습니다. 의료계는 의대 정원 확대가 의료 교육의 질을 저하시킬 것이라는 우려를 지속적으로 제기해왔습니다. 실제로, 교육부가 의과대학을 설치·운영하는 40개 대학에 공문을 보내 2025학년도 입학정원 증원 수요 조사에 착수했다는 보도가 있었습니다. 이는 의료계와 정부 사이에서 의대교육의 질 저하에 대한 우려가 여전히 존재함을 보여줍니다(연합뉴스, 2024년 2월 23일). 의료계는 "의대교육 질 저하 불가피"라는 입장을 견지하고 있으며, 정부는 "충분히 수용 가능한 수준"이라고 반박하고 있습니다. 이러한 상황은 의대 정원 확대가 의료 교육의 질에 미치는 영향에 대한 심도 있는 검토와 대책 마련이 필요함을 시사합니다.
#
# 출처: [연합뉴스](https://www.yna.co.kr/view/AKR20240223132600530)
#
#
# (Government(대한민국 정부)): 의사협회의 주장에 대해 반박하겠습니다. 의료 교육의 질 저하에 대한 우려는 중요한 문제이며, 정부 역시 이에 대해 심도 있는 검토와 대책 마련에 주력하고 있습니다. 그러나 의료계의 우려와는 달리, 의대 정원 확대가 반드시 의료 교육의 질 저하로 이어지는 것은 아닙니다. 정부는 의대 정원을 확대하는 과정에서 의료 교육의 질을 유지하고 향상시킬 수 있는 다양한 방안을 모색하고 있습니다. 예를 들어, 교육 인프라의 확충, 교육 프로그램의 개선, 실습 기회의 확대 등을 통해 의료 교육의 질을 높이는 데 주력하고 있습니다.
#
# 또한, 의료 인력의 부족 문제는 단순히 의료 교육의 질 문제로 환원될 수 없는, 국민 건강과 직결된 중대한 문제입니다. 한국보건사회연구원의 연구에 따르면, 의사 공급이 현재 수준으로 유지될 경우 2035년에는 의사 수가 수요 대비 2만7천 명 넘게 부족할 것이라는 추계가 나왔습니다. 이는 의료 인력의 절대적 부족 상황을 해결하기 위해 의대 정원 확대가 필수적임을 시사합니다.
#
# 정부는 의대 정원 확대와 함께 의료 교육의 질을 보장하고, 의료 인력의 적절한 분배와 활용을 위한 종합적인 대책을 마련하고 있습니다. 이러한 노력을 통해 필수 의료와 지역 의료의 부족 문제를 해결하고, 국민들에게 더 나은 의료 서비스를 제공할 수 있을 것입니다. 따라서, 의대 정원 확대는 단순히 의사 수를 늘리는 것이 아니라, 국민 건강을 보호하고 의료 서비스의 질을 향상시키기 위한 필수적인 조치입니다.
#
# 출처: 연합뉴스, "의대 정원 확대 필요성 강조" [연합뉴스](https://www.yna.co.kr/view/AKR20221224035500530)
#
#
# (Doctor Union(의사협회)): 정부의 주장에 대해 반박하겠습니다. 정부는 의대 정원 확대가 의료 교육의 질 저하로 이어지지 않도록 다양한 방안을 모색하고 있다고 주장하고 있지만, 실제로 의료 교육의 질을 유지하고 향상시키기 위한 구체적인 계획과 실행 방안이 충분히 제시되지 않고 있습니다. 의료 교육의 질은 단순히 교육 인프라의 확충이나 교육 프로그램의 개선만으로 해결될 수 있는 문제가 아닙니다. 의료 교육은 실습 기회의 질, 교육 과정의 내용, 교육을 담당하는 교수진의 전문성 등 다양한 요소에 의해 영향을 받습니다. 따라서, 의대 정원을 확대하면서 동시에 이러한 다양한 요소들을 고려한 종합적인 대책이 마련되어야 합니다.
#
# 또한, 의료 인력의 절대적 부족 문제를 해결하기 위한 의대 정원 확대가 필수적이라는 정부의 주장에 대해서도 반박하겠습니다. 의료 인력의 부족 문제는 단순히 의사 수의 절대적인 부족보다는 의료 인력의 불균형적인 분포와 활용의 문제가 더 큰 원인입니다. 특히, 지역별, 전문별 의료 인력의 불균형은 의료 서비스 접근성의 격차를 초래하며, 이러한 문제는 의대 정원을 확대한다고 해서 자동적으로 해결되지 않습니다. 따라서, 의료 인력의 효율적인 분배와 활용을 위한 정책적 접근이 우선되어야 합니다.
#
# 정부는 의대 정원 확대를 통해 국민 건강을 보호하고 의료 서비스의 질을 향상시키기 위한 필수적인 조치라고 주장하지만, 실제로는 의료 인력의 효율적인 활용과 의료 시스템 내의 구조적 문제 해결에 더욱 집중해야 합니다. 의료 인력의 적절한 분배와 활용, 의료 시스템의 개선 없이는 의대 정원 확대만으로는 국민 건강 보호와 의료 서비스의 질 향상을 달성하기 어렵습니다. 따라서, 의료계와 정부는 의대 정원 확대의 필요성과 효과에 대해 심도 있는 논의를 지속하며, 의료 인력의 효율적인 활용과 의료 시스템의 개선을 위한 구체적인 방안을 모색해야 합니다.
#
#
# (Government(대한민국 정부)): Government(대한민국 정부): 의사협회의 주장에 대해 반박하겠습니다. 의료 인력의 불균형적인 분포와 활용 문제를 해결하기 위한 정책적 접근이 필요하다는 점에는 동의합니다. 그러나 이러한 문제를 해결하는 동시에, 의료 인력의 절대적 부족 문제도 해결해야 합니다. 의료 인력의 불균형적인 분포는 중요한 문제이지만, 이를 해결하기 위해서는 충분한 의료 인력이 전제되어야 합니다. 의료 인력의 절대적 부족 상황에서는, 분배와 활용의 최적화만으로는 국민 건강 보호와 의료 서비스의 질 향상을 달성하기 어렵습니다.
#
# 정부는 의대 정원 확대와 함께 의료 인력의 효율적인 분배와 활용, 의료 시스템의 개선을 위한 다양한 정책을 동시에 추진하고 있습니다. 예를 들어, 지역 의료 인력의 부족 문제를 해결하기 위해 지역 의사제도를 도입하고, 의료 인력의 지역별, 전문별 불균형을 해소하기 위한 유인책을 마련하는 등의 노력을 기울이고 있습니다. 이러한 정책들은 의대 정원 확대와 병행하여 추진되며, 의료 인력의 적절한 분배와 활용을 통해 국민 건강 보호와 의료 서비스의 질 향상을 목표로 합니다.
#
# 또한, 의료 교육의 질을 유지하고 향상시키기 위한 구체적인 계획과 실행 방안에 대해서도 정부는 충분히 고민하고 있습니다. 의료 교육의 질을 보장하기 위해 교육 인프라의 확충, 교육 프로그램의 개선, 실습 기회의 질적 향상 등에 필요한 자원을 투입하고 있으며, 이를 통해 의료 교육의 질을 높이고 의료 서비스의 질을 향상시키기 위한 노력을 지속하고 있습니다.
#
# 정부는 의대 정원 확대를 포함한 종합적인 접근 방식을 통해 국민 건강을 보호하고 의료 서비스의 질을 향상시키기 위한 필수적인 조치를 취하고 있습니다. 의료계와 정부는 이러한 목표를 달성하기 위해 상호 협력하며, 의료 인력의 효율적인 활용과 의료 시스템의 개선을 위한 구체적인 방안을 함께 모색해야 합니다.
#
#
# (Doctor Union(의사협회)): 정부의 주장에 대해 반박하겠습니다. 정부는 의대 정원 확대와 함께 의료 인력의 효율적인 분배와 활용, 의료 시스템의 개선을 위한 다양한 정책을 추진하고 있다고 주장합니다. 그러나 의료 인력의 절대적 부족 문제를 해결하기 위한 의대 정원 확대가 실제로 의료 서비스의 질 향상과 국민 건강 보호에 기여할 수 있을지에 대한 의문이 제기됩니다. 의료 인력의 불균형적인 분포와 활용 문제는 의대 정원 확대만으로 해결될 수 있는 문제가 아니며, 이러한 문제를 해결하기 위해서는 보다 근본적인 접근이 필요합니다.
#
# 실제로, 의료 인력의 지역별, 전문별 불균형 문제는 의대 정원을 확대한다고 해서 자동적으로 해결되지 않습니다. 지역 의료 인력의 부족 문제를 해결하기 위한 지역 의사제도와 같은 정책이 실제로 효과적으로 작동하고 있는지에 대한 검증이 필요합니다. 또한, 의료 교육의 질을 유지하고 향상시키기 위한 구체적인 계획과 실행 방안이 충분히 제시되지 않고 있는 상황에서, 의대 정원을 확대하는 것이 의료 교육의 질 저하로 이어질 수 있는 위험을 간과해서는 안 됩니다.
#
# 따라서, 의료계와 정부는 의대 정원 확대의 필요성과 효과에 대해 심도 있는 논의를 지속하며, 의료 인력의 효율적인 활용과 의료 시스템의 개선을 위한 구체적인 방안을 모색해야 합니다. 의료 인력의 적절한 분배와 활용, 의료 시스템의 개선 없이는 의대 정원 확대만으로는 국민 건강 보호와 의료 서비스의 질 향상을 달성하기 어렵습니다.
#
#
# (Government(대한민국 정부)): Government(대한민국 정부): 의사협회의 주장에 대해 반박하겠습니다. 의료 인력의 불균형적인 분배와 활용 문제는 실제로 중요한 문제입니다. 그러나 이 문제를 해결하기 위한 근본적인 접근 방법 중 하나는 충분한 의료 인력의 확보입니다. 의료 인력의 절대적 부족 상황에서는, 아무리 효율적인 분배와 활용 정책을 마련한다 하더라도 국민 건강 보호와 의료 서비스의 질 향상을 달성하는 데 한계가 있습니다.
#
# 정부는 의대 정원 확대와 함께 의료 인력의 효율적인 분배와 활용, 의료 시스템의 개선을 위한 다양한 정책을 추진하고 있습니다. 예를 들어, 지역 의료 인력의 부족 문제를 해결하기 위해 지역 의사제도를 도입하고, 의료 인력의 지역별, 전문별 불균형을 해소하기 위한 유인책을 마련하는 등의 노력을 기울이고 있습니다. 이러한 정책들은 의대 정원 확대와 병행하여 추진되며, 의료 인력의 적절한 분배와 활용을 통해 국민 건강 보호와 의료 서비스의 질 향상을 목표로 합니다.
#
# 또한, 의료 교육의 질을 유지하고 향상시키기 위한 구체적인 계획과 실행 방안에 대해서도 정부는 충분히 고민하고 있습니다. 의료 교육의 질을 보장하기 위해 교육 인프라의 확충, 교육 프로그램의 개선, 실습 기회의 질적 향상 등에 필요한 자원을 투입하고 있으며, 이를 통해 의료 교육의 질을 높이고 의료 서비스의 질을 향상시키기 위한 노력을 지속하고 있습니다.
#
# 정부는 의대 정원 확대를 포함한 종합적인 접근 방식을 통해 국민 건강을 보호하고 의료 서비스의 질을 향상시키기 위한 필수적인 조치를 취하고 있습니다. 의료계와 정부는 이러한 목표를 달성하기 위해 상호 협력하며, 의료 인력의 효율적인 활용과 의료 시스템의 개선을 위한 구체적인 방안을 함께 모색해야 합니다.
#
#
# (Doctor Union(의사협회)): 정부의 주장에 대해 반박하겠습니다. 정부는 의대 정원 확대와 함께 의료 인력의 효율적인 분배와 활용, 의료 시스템의 개선을 위한 다양한 정책을 추진하고 있다고 주장하고 있지만, 의료 인력의 절대적 부족 문제를 해결하기 위한 의대 정원 확대가 실제로 의료 서비스의 질 향상과 국민 건강 보호에 기여할 수 있을지에 대한 의문이 제기됩니다. 의료 인력의 불균형적인 분배와 활용 문제는 의대 정원 확대만으로 해결될 수 있는 문제가 아니며, 이러한 문제를 해결하기 위해서는 보다 근본적인 접근이 필요합니다.
#
# 실제로, 의료 인력의 지역별, 전문별 불균형 문제는 의대 정원을 확대한다고 해서 자동적으로 해결되지 않습니다. 지역 의료 인력의 부족 문제를 해결하기 위한 지역 의사제도와 같은 정책이 실제로 효과적으로 작동하고 있는지에 대한 검증이 필요합니다. 또한, 의료 교육의 질을 유지하고 향상시키기 위한 구체적인 계획과 실행 방안이 충분히 제시되지 않고 있는 상황에서, 의대 정원을 확대하는 것이 의료 교육의 질 저하로 이어질 수 있는 위험을 간과해서는 안 됩니다.
#
# 따라서, 의료계와 정부는 의대 정원 확대의 필요성과 효과에 대해 심도 있는 논의를 지속하며, 의료 인력의 효율적인 활용과 의료 시스템의 개선을 위한 구체적인 방안을 모색해야 합니다. 의료 인력의 적절한 분배와 활용, 의료 시스템의 개선 없이는 의대 정원 확대만으로는 국민 건강 보호와 의료 서비스의 질 향상을 달성하기 어렵습니다.
#
#
# (Government(대한민국 정부)): Government(대한민국 정부): 의사협회의 주장에 대해 반박하겠습니다. 의료 인력의 절대적 부족 문제와 불균형적인 분배 및 활용 문제는 서로 다른 차원의 문제입니다. 의료 인력의 절대적 부족 문제를 해결하지 않고서는, 불균형적인 분배 및 활용 문제를 해결하는 것이 실질적으로 불가능합니다. 의료 인력의 절대적 부족 상황에서는, 아무리 효율적인 분배와 활용 정책을 마련한다 하더라도 국민 건강 보호와 의료 서비스의 질 향상을 달성하는 데 한계가 있습니다.
#
# 정부는 의대 정원 확대와 함께 의료 인력의 효율적인 분배와 활용, 의료 시스템의 개선을 위한 다양한 정책을 추진하고 있습니다. 예를 들어, 지역 의료 인력의 부족 문제를 해결하기 위해 지역 의사제도를 도입하고, 의료 인력의 지역별, 전문별 불균형을 해소하기 위한 유인책을 마련하는 등의 노력을 기울이고 있습니다. 이러한 정책들은 의대 정원 확대와 병행하여 추진되며, 의료 인력의 적절한 분배와 활용을 통해 국민 건강 보호와 의료 서비스의 질 향상을 목표로 합니다.
#
# 또한, 의료 교육의 질을 유지하고 향상시키기 위한 구체적인 계획과 실행 방안에 대해서도 정부는 충분히 고민하고 있습니다. 의료 교육의 질을 보장하기 위해 교육 인프라의 확충, 교육 프로그램의 개선, 실습 기회의 질적 향상 등에 필요한 자원을 투입하고 있으며, 이를 통해 의료 교육의 질을 높이고 의료 서비스의 질을 향상시키기 위한 노력을 지속하고 있습니다.
#
# 정부는 의대 정원 확대를 포함한 종합적인 접근 방식을 통해 국민 건강을 보호하고 의료 서비스의 질을 향상시키기 위한 필수적인 조치를 취하고 있습니다. 의료계와 정부는 이러한 목표를 달성하기 위해 상호 협력하며, 의료 인력의 효율적인 활용과 의료 시스템의 개선을 위한 구체적인 방안을 함께 모색해야 합니다.
#
#
# (Doctor Union(의사협회)): 이 대화는 이미 종료되었습니다. 다른 질문이 있으시면 언제든지 물어보세요.
#
#
# (Government(대한민국 정부)): 이 대화는 이미 종료되었습니다. 다른 질문이 있으시면 언제든지 물어보세요.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 19
#      15 print("\n")
#      17 while n < max_iters:  # 최대 반복 횟수까지 반복합니다.
#      18     name, message = (
# ---> 19         simulator.step()
#      20     )  # 시뮬레이터의 다음 단계를 실행하고 발언자와 메시지를 받아옵니다.
#      21     print(f"({name}): {message}")  # 발언자와 메시지를 출력합니다.
#      22     print("\n")
#
# Cell In[3], line 36, in DialogueSimulator.step(self)
#      33 speaker = self.agents[speaker_idx]
#      35 # 2. 다음 발언자에게 메시지를 전송합니다.
# ---> 36 message = speaker.send()
#      38 # 3. 모든 에이전트가 메시지를 받습니다.
#      39 for receiver in self.agents:
#
# Cell In[39], line 27, in DialogueAgentWithTools.send(self)
#      24 agent_executor = AgentExecutor(agent=agent, tools=self.tools, verbose=False)
#      25 # AI 메시지를 생성합니다.
#      26 message = AIMessage(
# ---> 27     content=agent_executor.invoke(
#      28         {
#      29             "input": "\n".join(
#      30                 [self.system_message.content]
#      31                 + [self.prefix]
#      32                 + self.message_history
#      33             )
#      34         }
#      35     )["output"]
#      36 )
#      38 # 생성된 메시지의 내용을 반환합니다.
#      39 return message.content
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/langchain/chains/base.py:163, in Chain.invoke(self, input, config, **kwargs)
#     161 except BaseException as e:
#     162     run_manager.on_chain_error(e)
# --> 163     raise e
#     164 run_manager.on_chain_end(outputs)
#     166 if include_run_info:
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/langchain/chains/base.py:153, in Chain.invoke(self, input, config, **kwargs)
#     150 try:
#     151     self._validate_inputs(inputs)
#     152     outputs = (
# --> 153         self._call(inputs, run_manager=run_manager)
#     154         if new_arg_supported
#     155         else self._call(inputs)
#     156     )
#     158     final_outputs: Dict[str, Any] = self.prep_outputs(
#     159         inputs, outputs, return_only_outputs
#     160     )
#     161 except BaseException as e:
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/langchain/agents/agent.py:1391, in AgentExecutor._call(self, inputs, run_manager)
#    1389 # We now enter the agent loop (until it returns something).
#    1390 while self._should_continue(iterations, time_elapsed):
# -> 1391     next_step_output = self._take_next_step(
#    1392         name_to_tool_map,
#    1393         color_mapping,
#    1394         inputs,
#    1395         intermediate_steps,
#    1396         run_manager=run_manager,
#    1397     )
#    1398     if isinstance(next_step_output, AgentFinish):
#    1399         return self._return(
#    1400             next_step_output, intermediate_steps, run_manager=run_manager
#    1401         )
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/langchain/agents/agent.py:1097, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1088 def _take_next_step(
#    1089     self,
#    1090     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1094     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1095 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1096     return self._consume_next_step(
# -> 1097         [
#    1098             a
#    1099             for a in self._iter_next_step(
#    1100                 name_to_tool_map,
#    1101                 color_mapping,
#    1102                 inputs,
#    1103                 intermediate_steps,
#    1104                 run_manager,
#    1105             )
#    1106         ]
#    1107     )
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/langchain/agents/agent.py:1097, in <listcomp>(.0)
#    1088 def _take_next_step(
#    1089     self,
#    1090     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1094     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1095 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1096     return self._consume_next_step(
# -> 1097         [
#    1098             a
#    1099             for a in self._iter_next_step(
#    1100                 name_to_tool_map,
#    1101                 color_mapping,
#    1102                 inputs,
#    1103                 intermediate_steps,
#    1104                 run_manager,
#    1105             )
#    1106         ]
#    1107     )
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/langchain/agents/agent.py:1125, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1122     intermediate_steps = self._prepare_intermediate_steps(intermediate_steps)
#    1124     # Call the LLM to see what to do.
# -> 1125     output = self.agent.plan(
#    1126         intermediate_steps,
#    1127         callbacks=run_manager.get_child() if run_manager else None,
#    1128         **inputs,
#    1129     )
#    1130 except OutputParserException as e:
#    1131     if isinstance(self.handle_parsing_errors, bool):
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/langchain/agents/agent.py:486, in RunnableMultiActionAgent.plan(self, intermediate_steps, callbacks, **kwargs)
#     480 # Use streaming to make sure that the underlying LLM is invoked in a streaming
#     481 # fashion to make it possible to get access to the individual LLM tokens
#     482 # when using stream_log with the Agent Executor.
#     483 # Because the response from the plan is not a generator, we need to
#     484 # accumulate the output into final output and return that.
#     485 final_output: Any = None
# --> 486 for chunk in self.runnable.stream(inputs, config={"callbacks": callbacks}):
#     487     if final_output is None:
#     488         final_output = chunk
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/langchain_core/runnables/base.py:2460, in RunnableSequence.stream(self, input, config, **kwargs)
#    2454 def stream(
#    2455     self,
#    2456     input: Input,
#    2457     config: Optional[RunnableConfig] = None,
#    2458     **kwargs: Optional[Any],
#    2459 ) -> Iterator[Output]:
# -> 2460     yield from self.transform(iter([input]), config, **kwargs)
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/langchain_core/runnables/base.py:2447, in RunnableSequence.transform(self, input, config, **kwargs)
#    2441 def transform(
#    2442     self,
#    2443     input: Iterator[Input],
#    2444     config: Optional[RunnableConfig] = None,
#    2445     **kwargs: Optional[Any],
#    2446 ) -> Iterator[Output]:
# -> 2447     yield from self._transform_stream_with_config(
#    2448         input,
#    2449         self._transform,
#    2450         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    2451         **kwargs,
#    2452     )
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/langchain_core/runnables/base.py:1527, in Runnable._transform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    1525 try:
#    1526     while True:
# -> 1527         chunk: Output = context.run(next, iterator)  # type: ignore
#    1528         yield chunk
#    1529         if final_output_supported:
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/langchain_core/runnables/base.py:2411, in RunnableSequence._transform(self, input, run_manager, config)
#    2402 for step in steps:
#    2403     final_pipeline = step.transform(
#    2404         final_pipeline,
#    2405         patch_config(
#    (...)
#    2408         ),
#    2409     )
# -> 2411 for output in final_pipeline:
#    2412     yield output
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/langchain_core/runnables/base.py:1051, in Runnable.transform(self, input, config, **kwargs)
#    1048 final: Input
#    1049 got_first_val = False
# -> 1051 for chunk in input:
#    1052     if not got_first_val:
#    1053         final = _adapt_first_streaming_chunk(chunk)  # type: ignore
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/langchain_core/runnables/base.py:4194, in RunnableBindingBase.transform(self, input, config, **kwargs)
#    4188 def transform(
#    4189     self,
#    4190     input: Iterator[Input],
#    4191     config: Optional[RunnableConfig] = None,
#    4192     **kwargs: Any,
#    4193 ) -> Iterator[Output]:
# -> 4194     yield from self.bound.transform(
#    4195         input,
#    4196         self._merge_configs(config),
#    4197         **{**self.kwargs, **kwargs},
#    4198     )
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/langchain_core/runnables/base.py:1068, in Runnable.transform(self, input, config, **kwargs)
#    1061             raise TypeError(
#    1062                 f"Failed while trying to add together "
#    1063                 f"type {type(final)} and {type(chunk)}."
#    1064                 f"These types should be addable for transform to work."
#    1065             )
#    1067 if got_first_val:
# -> 1068     yield from self.stream(final, config, **kwargs)
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:258, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     251 except BaseException as e:
#     252     run_manager.on_llm_error(
#     253         e,
#     254         response=LLMResult(
#     255             generations=[[generation]] if generation else []
#     256         ),
#     257     )
# --> 258     raise e
#     259 else:
#     260     run_manager.on_llm_end(LLMResult(generations=[[generation]]))
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:241, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     239 generation: Optional[ChatGenerationChunk] = None
#     240 try:
# --> 241     for chunk in self._stream(
#     242         messages, stop=stop, run_manager=run_manager, **kwargs
#     243     ):
#     244         chunk.message.response_metadata = _gen_info_and_msg_metadata(chunk)
#     245         yield chunk.message
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:419, in ChatOpenAI._stream(self, messages, stop, run_manager, **kwargs)
#     416 params = {**params, **kwargs, "stream": True}
#     418 default_chunk_class = AIMessageChunk
# --> 419 for chunk in self.client.create(messages=message_dicts, **params):
#     420     if not isinstance(chunk, dict):
#     421         chunk = chunk.model_dump()
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/openai/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/openai/resources/chat/completions.py:663, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     611 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     612 def create(
#     613     self,
#    (...)
#     661     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     662 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 663     return self._post(
#     664         "/chat/completions",
#     665         body=maybe_transform(
#     666             {
#     667                 "messages": messages,
#     668                 "model": model,
#     669                 "frequency_penalty": frequency_penalty,
#     670                 "function_call": function_call,
#     671                 "functions": functions,
#     672                 "logit_bias": logit_bias,
#     673                 "logprobs": logprobs,
#     674                 "max_tokens": max_tokens,
#     675                 "n": n,
#     676                 "presence_penalty": presence_penalty,
#     677                 "response_format": response_format,
#     678                 "seed": seed,
#     679                 "stop": stop,
#     680                 "stream": stream,
#     681                 "temperature": temperature,
#     682                 "tool_choice": tool_choice,
#     683                 "tools": tools,
#     684                 "top_logprobs": top_logprobs,
#     685                 "top_p": top_p,
#     686                 "user": user,
#     687             },
#     688             completion_create_params.CompletionCreateParams,
#     689         ),
#     690         options=make_request_options(
#     691             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     692         ),
#     693         cast_to=ChatCompletion,
#     694         stream=stream or False,
#     695         stream_cls=Stream[ChatCompletionChunk],
#     696     )
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/openai/_base_client.py:1200, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1186 def post(
#    1187     self,
#    1188     path: str,
#    (...)
#    1195     stream_cls: type[_StreamT] | None = None,
#    1196 ) -> ResponseT | _StreamT:
#    1197     opts = FinalRequestOptions.construct(
#    1198         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1199     )
# -> 1200     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/openai/_base_client.py:889, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     880 def request(
#     881     self,
#     882     cast_to: Type[ResponseT],
#    (...)
#     887     stream_cls: type[_StreamT] | None = None,
#     888 ) -> ResponseT | _StreamT:
# --> 889     return self._request(
#     890         cast_to=cast_to,
#     891         options=options,
#     892         stream=stream,
#     893         stream_cls=stream_cls,
#     894         remaining_retries=remaining_retries,
#     895     )
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/openai/_base_client.py:918, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     915     kwargs["auth"] = self.custom_auth
#     917 try:
# --> 918     response = self._client.send(
#     919         request,
#     920         stream=stream or self._should_stream_response_body(request=request),
#     921         **kwargs,
#     922     )
#     923 except httpx.TimeoutException as err:
#     924     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/httpx/_client.py:915, in Client.send(self, request, stream, auth, follow_redirects)
#     907 follow_redirects = (
#     908     self.follow_redirects
#     909     if isinstance(follow_redirects, UseClientDefault)
#     910     else follow_redirects
#     911 )
#     913 auth = self._build_request_auth(request, auth)
# --> 915 response = self._send_handling_auth(
#     916     request,
#     917     auth=auth,
#     918     follow_redirects=follow_redirects,
#     919     history=[],
#     920 )
#     921 try:
#     922     if not stream:
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/httpx/_client.py:943, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     940 request = next(auth_flow)
#     942 while True:
# --> 943     response = self._send_handling_redirects(
#     944         request,
#     945         follow_redirects=follow_redirects,
#     946         history=history,
#     947     )
#     948     try:
#     949         try:
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/httpx/_client.py:980, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977 for hook in self._event_hooks["request"]:
#     978     hook(request)
# --> 980 response = self._send_single_request(request)
#     981 try:
#     982     for hook in self._event_hooks["response"]:
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/httpx/_client.py:1016, in Client._send_single_request(self, request)
#    1011     raise RuntimeError(
#    1012         "Attempted to send an async request with a sync Client instance."
#    1013     )
#    1015 with request_context(request=request):
# -> 1016     response = transport.handle_request(request)
#    1018 assert isinstance(response.stream, SyncByteStream)
#    1020 response.request = request
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/httpx/_transports/default.py:231, in HTTPTransport.handle_request(self, request)
#     218 req = httpcore.Request(
#     219     method=request.method,
#     220     url=httpcore.URL(
#    (...)
#     228     extensions=request.extensions,
#     229 )
#     230 with map_httpcore_exceptions():
# --> 231     resp = self._pool.handle_request(req)
#     233 assert isinstance(resp.stream, typing.Iterable)
#     235 return Response(
#     236     status_code=resp.status,
#     237     headers=resp.headers,
#     238     stream=ResponseStream(resp.stream),
#     239     extensions=resp.extensions,
#     240 )
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     266     with ShieldCancellation():
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     elif not self._connection.is_available():
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     131     with Trace("response_closed", logger, request) as trace:
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/httpcore/_sync/http11.py:111, in HTTP11Connection.handle_request(self, request)
#     101     pass
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#     119 return Response(
#     120     status=status,
#     121     headers=headers,
#    (...)
#     127     },
#     128 )
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/httpcore/_sync/http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     173 timeout = timeouts.get("read", None)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#     178         break
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/httpcore/_sync/http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/miniconda3/envs/py-test/lib/python3.10/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~/miniconda3/envs/py-test/lib/python3.10/ssl.py:1292, in SSLSocket.recv(self, buflen, flags)
#    1288     if flags != 0:
#    1289         raise ValueError(
#    1290             "non-zero flags not allowed in calls to recv() on %s" %
#    1291             self.__class__)
# -> 1292     return self.read(buflen)
#    1293 else:
#    1294     return super().recv(buflen, flags)
#
# File ~/miniconda3/envs/py-test/lib/python3.10/ssl.py:1165, in SSLSocket.read(self, len, buffer)
#    1163         return self._sslobj.read(len, buffer)
#    1164     else:
# -> 1165         return self._sslobj.read(len)
#    1166 except SSLError as x:
#    1167     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
